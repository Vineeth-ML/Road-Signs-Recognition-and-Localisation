# %%
import os
import cv2
import torch
import numpy as np
import pandas as pd
from torch import nn
from PIL import Image
from matplotlib import patches
import matplotlib.pyplot as plt
import torchvision.transforms.functional as F
from torch.utils.data import Dataset, DataLoader

# https://universe.roboflow.com/roboflow-100/road-signs-6ih4y/dataset/2

# %%
class RoadSign(Dataset):
    def __init__(self, root_dir, split="train"):
        self.root_dir = root_dir
        # joing root_dir with split
        self.split_path = os.path.join(root_dir, split)
        # read annotations csv file as dataframe
        self.annot_df = pd.read_csv(os.path.join(self.split_path, "_annotations.csv"))
        # get the distinct classes
        self.classes = self.annot_df["class"].unique()
        # create dictionaries to map from and to class values.
        self.img_shape = (224, 224)
        self.class_to_int = dict(zip(self.classes, range(len(self.classes))))
        self.int_to_class = dict(zip(range(len(self.classes)), self.classes))
    
    def __len__(self):
        return self.annot_df.shape[0]
    
    def resize_image(self, image):
        return image.resize(self.img_shape)
    
    def map_coorinates(self, bbox_info, source_size=(640, 640)):
        sh, sw = source_size
        dh, dw = self.img_shape
        # To scale from source to destination, multiply with sw/sh
        h_ratio = dh/sh
        # To scale from source to destination, multiply with dw/dh
        w_ratio = dw/sw
        x_min, y_min, x_max, y_max = bbox_info
        x_min, x_max = int(x_min*w_ratio), int(x_max*w_ratio)
        y_min, y_max = int(y_min*h_ratio), int(y_max*h_ratio)
        return (x_min, y_min, x_max, y_max)

    
    def __getitem__(self, index):
        # get the requested row from dataframe
        row = self.annot_df.iloc[index]
        # get the image path
        img_path = os.path.join(self.split_path, row["filename"])
        # read the image path
        image_bgr = cv2.imread(img_path)
        image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)
        resized_image = cv2.resize(image_rgb, self.img_shape)
        tensor_image = F.to_tensor(resized_image)
        # Get the integer value of class
        class_val = torch.tensor(self.class_to_int.get(row["class"]))
        # Get the values of bounding box
        bbox_info = row.loc["xmin":"ymax"].to_list()
        resized_bbox_info = torch.Tensor(self.map_coorinates(bbox_info))
        
        return (tensor_image, class_val, resized_bbox_info)


data = RoadSign(root_dir="road signs")
int_to_class = data.int_to_class

# %%
print(f"Total Images: {len(data)}")
# Out:
# Total Images: 1502

# %%
data.annot_df.head()
# Out:
#                                             filename  width  height  \
# 0  peringatan-alat-pemberi-isyarat-lalu-lintas--6...    640     640
# 1  larangan-berhenti--33-_jpg.rf.cb74ee461cb46fa7...    640     640
# 2  larangan-masuk-bagi-kendaraan-bermotor-dan-tid...    640     640
# 3  perintah-masuk-jalur-kiri--15-_jpg.rf.cc263692...    640     640
# 4  perintah-masuk-jalur-kiri--24-_jpg.rf.cc3cd4a5...    640     640
#
#              class  xmin  ymin  xmax  ymax
# 0    traffic_light   250   124   464   514
# 1      do_not_stop    96   132   324   448
# 2     do_not_enter   224   181   375   406
# 3  enter_left_lane   316   107   534   362
# 4  enter_left_lane   209   172   323   350

# %%
data.annot_df["class"].value_counts().plot(kind="bar")
plt.title("Value counts of class")
# Out:
# Text(0.5, 1.0, 'Value counts of class')

# %%
def display_img_mask(img, y, mask, ax=None, linewidth=2, edgecolor="blue", facecolor="none"):
    xmin, ymin, xmax, ymax = mask
    # get width of bbox
    width = xmax - xmin
    # get height of bbox
    height = ymax - ymin
    # get the rectangle patch
    rect = patches.Rectangle((xmin, ymin), width, height,
                             linewidth=linewidth,
                             edgecolor=edgecolor,
                             facecolor=facecolor)
    if ax is None:
        fig, ax = plt.subplots()

    # show the image
    ax.imshow(img.numpy().transpose(1, 2, 0))
    # add the patch
    ax.add_patch(rect)
    # set the title to class
    ax.set_title(int_to_class.get(int(y)))

# %%
image, y, bbox = data[2]
display_img_mask(image, y, bbox)

# %%
# plt.figure(figsize=(10, 10))
fig, ax = plt.subplots(5, 5)
fig.set_size_inches((10, 10))
for i in range(5):
    for j in range(5):
        idx = i * 5 + j + 20
        this_ax = ax[i][j]
        image, y, bbox = data[idx]
        display_img_mask(image, y, bbox, ax=this_ax, linewidth=1)
        this_ax.set_axis_off()

# %%
batchsize = 16
loader = DataLoader(data, batch_size=batchsize)

# %%
images_, ys_, bboxes_ = next(iter(loader))

# %% [markdown]
# ## Model Building

# %%
from torchvision.models import resnet18, ResNet18_Weights

# %%
class SignDetectionModel(nn.Module):
    def __init__(self, n_outputs=4):
        super().__init__()
        self.n_outputs = n_outputs
        self.input = nn.Conv2d(in_channels=3, out_channels=3, kernel_size=(3, 3), padding="same")
        self.backbone = resnet18(weights=ResNet18_Weights.IMAGENET1K_V1)
        # For bounding box ((x_min, y_min), (x_max, y_max))
        self.bbox_op1 = nn.Linear(in_features=1000, out_features=100)
        self.bbox_op2 = nn.Linear(in_features=100, out_features=10)
        self.bbox_op3 = nn.Linear(in_features=10, out_features=n_outputs)
        # For class value
        self.class_op1 = nn.Linear(in_features=1000, out_features=100)
        self.class_op2 = nn.Linear(in_features=100, out_features=21)
        # self.class_op3 = nn.Softmax(dim=1)

    def forward(self, x):
        x = self.input(x)
        x = self.backbone(x)
        # For bounding box
        x_bbox = self.bbox_op1(x)
        x_bbox = self.bbox_op2(x_bbox)
        x_bbox = self.bbox_op3(x_bbox)
        # For class value
        x_class = self.class_op1(x)
        x_class = self.class_op2(x_class)

        return (x_class, x_bbox)

# %%
from torch.nn import CrossEntropyLoss, SmoothL1Loss
from torch.optim import Adam

loss_fn_bbox = SmoothL1Loss()
loss_fn_class = CrossEntropyLoss()

model = SignDetectionModel()

optim = Adam(model.parameters())

# %%
# ims_, ys_, bboxes_ = next(iter(loader))

# y_preds, box_preds = model(ims_)

# %%
device = "cpu"
if torch.cuda.is_available():
    device = "cuda"
elif torch.backends.mps.is_available():
    device = "mps"

device
# Out:
# 'cuda'

# %%
def train_model(loader, val_loader, model, loss_fns, optim, n_epochs=20):
    class_losses_train = []
    class_losses_valid = []
    bbox_losses_train = []
    bbox_losses_valid = []
    class_loss_fn = loss_fns["class"]
    bbox_loss_fn = loss_fns["bbox"]
    for epoch in range(1, n_epochs+1):
        class_losses_batch = []
        bbox_losses_batch = []
        model.train()
        for i, (images, ys, bboxes) in enumerate(loader):
            # Transfer to device
            images = images.to(device)
            ys = ys.to(device)
            bboxes = bboxes.to(device)

            y_preds, bbox_preds = model(images)
            y_loss = class_loss_fn(y_preds, ys)
            bbox_loss = bbox_loss_fn(bbox_preds, bboxes)
            total_loss = 10 * y_loss + bbox_loss
            
            optim.zero_grad()
            total_loss.backward()
            optim.step()

            class_losses_batch.append(y_loss.item())
            bbox_losses_batch.append(bbox_loss.item())
            if i % 10 == 0:
                print(f"[EPOCH {epoch}] - [B {i}/{len(loader)}] - Class loss: {y_loss.item():0.3f}")
                print(f"[EPOCH {epoch}] - [B {i}/{len(loader)}] - Bbox loss : {bbox_loss.item():0.3f}")
        
        class_losses_train.append(np.mean(class_losses_batch))
        bbox_losses_train.append(np.mean(bbox_losses_batch))

        # Validation
        class_losses_batch_valid = []
        bbox_losses_batch_valid = []
        model.eval()
        for i, (images, ys, bboxes) in enumerate(val_loader):
            # Transfer to device
            images = images.to(device)
            ys = ys.to(device)
            bboxes = bboxes.to(device)

            y_preds, bbox_preds = model(images)
            y_loss = class_loss_fn(y_preds, ys)
            bbox_loss = bbox_loss_fn(bbox_preds, bboxes)

            class_losses_batch_valid.append(y_loss.item())
            bbox_losses_batch_valid.append(bbox_loss.item())
                
        class_losses_valid.append(np.mean(class_losses_batch_valid))
        bbox_losses_valid.append(np.mean(bbox_losses_batch_valid))

        print(f"[EPOCH {epoch}] - [EVAL] - Class loss: {class_losses_valid[-1]:0.3f}")
        print(f"[EPOCH {epoch}] - [EVAL] - Bbox loss : {bbox_losses_valid[-1]:0.3f}")
        print()
        
        
    scores = {
        "train_class": class_losses_train,
        "train_bbox": bbox_losses_train,
        "valid_class": class_losses_valid,
        "valid_bbox": bbox_losses_valid,
    }
    return scores

# %%
val_data = RoadSign(root_dir="road signs", split="valid")
val_loader = DataLoader(val_data, batch_size=batchsize)

# %%
loss_fns = {"class": loss_fn_class, "bbox": loss_fn_bbox}
model.to(device)

n_epochs = 50
metrics = train_model(loader, val_loader, model, loss_fns, optim, n_epochs=n_epochs)
torch.save(model.state_dict(), "road_sign_model.pth")
# Out:
# [EPOCH 1] - [B 0/94] - Class loss: 3.086
# [EPOCH 1] - [B 0/94] - Bbox loss : 100.875
# [EPOCH 1] - [B 10/94] - Class loss: 4.234
# [EPOCH 1] - [B 10/94] - Bbox loss : 96.735
# [EPOCH 1] - [B 20/94] - Class loss: 3.484
# [EPOCH 1] - [B 20/94] - Bbox loss : 62.461
# [EPOCH 1] - [B 30/94] - Class loss: 2.920
# [EPOCH 1] - [B 30/94] - Bbox loss : 34.249
# [EPOCH 1] - [B 40/94] - Class loss: 2.126
# [EPOCH 1] - [B 40/94] - Bbox loss : 18.929
# [EPOCH 1] - [B 50/94] - Class loss: 2.337
# [EPOCH 1] - [B 50/94] - Bbox loss : 30.702
# [EPOCH 1] - [B 60/94] - Class loss: 2.376
# [EPOCH 1] - [B 60/94] - Bbox loss : 20.350
# [EPOCH 1] - [B 70/94] - Class loss: 3.124
# [EPOCH 1] - [B 70/94] - Bbox loss : 32.026
# [EPOCH 1] - [B 80/94] - Class loss: 1.752
# [EPOCH 1] - [B 80/94] - Bbox loss : 19.893
# [EPOCH 1] - [B 90/94] - Class loss: 0.797
# [EPOCH 1] - [B 90/94] - Bbox loss : 25.936
# [EPOCH 1] - [EVAL] - Class loss: 9.784
# [EPOCH 1] - [EVAL] - Bbox loss : 20.621
#
# [EPOCH 2] - [B 0/94] - Class loss: 2.297
# [EPOCH 2] - [B 0/94] - Bbox loss : 19.165
# [EPOCH 2] - [B 10/94] - Class loss: 1.582
# [EPOCH 2] - [B 10/94] - Bbox loss : 35.233
# [EPOCH 2] - [B 20/94] - Class loss: 0.618
# [EPOCH 2] - [B 20/94] - Bbox loss : 23.349
# [EPOCH 2] - [B 30/94] - Class loss: 0.988
# [EPOCH 2] - [B 30/94] - Bbox loss : 13.679
# [EPOCH 2] - [B 40/94] - Class loss: 0.806
# [EPOCH 2] - [B 40/94] - Bbox loss : 13.883
# [EPOCH 2] - [B 50/94] - Class loss: 1.039
# [EPOCH 2] - [B 50/94] - Bbox loss : 26.484
# [EPOCH 2] - [B 60/94] - Class loss: 1.764
# [EPOCH 2] - [B 60/94] - Bbox loss : 19.048
# [EPOCH 2] - [B 70/94] - Class loss: 0.866
# [EPOCH 2] - [B 70/94] - Bbox loss : 29.233
# [EPOCH 2] - [B 80/94] - Class loss: 0.396
# [EPOCH 2] - [B 80/94] - Bbox loss : 18.052
# [EPOCH 2] - [B 90/94] - Class loss: 0.228
# [EPOCH 2] - [B 90/94] - Bbox loss : 26.720
# [EPOCH 2] - [EVAL] - Class loss: 11.052
# [EPOCH 2] - [EVAL] - Bbox loss : 20.411
#
# [EPOCH 3] - [B 0/94] - Class loss: 1.104
# [EPOCH 3] - [B 0/94] - Bbox loss : 20.066
# [EPOCH 3] - [B 10/94] - Class loss: 1.003
# [EPOCH 3] - [B 10/94] - Bbox loss : 33.620
# [EPOCH 3] - [B 20/94] - Class loss: 0.757
# [EPOCH 3] - [B 20/94] - Bbox loss : 21.445
# [EPOCH 3] - [B 30/94] - Class loss: 1.125
# [EPOCH 3] - [B 30/94] - Bbox loss : 13.842
# [EPOCH 3] - [B 40/94] - Class loss: 0.362
# [EPOCH 3] - [B 40/94] - Bbox loss : 12.359
# [EPOCH 3] - [B 50/94] - Class loss: 0.671
# [EPOCH 3] - [B 50/94] - Bbox loss : 25.405
# [EPOCH 3] - [B 60/94] - Class loss: 0.733
# [EPOCH 3] - [B 60/94] - Bbox loss : 17.094
# [EPOCH 3] - [B 70/94] - Class loss: 1.346
# [EPOCH 3] - [B 70/94] - Bbox loss : 30.748
# [EPOCH 3] - [B 80/94] - Class loss: 0.496
# [EPOCH 3] - [B 80/94] - Bbox loss : 17.885
# [EPOCH 3] - [B 90/94] - Class loss: 0.074
# [EPOCH 3] - [B 90/94] - Bbox loss : 23.426
# [EPOCH 3] - [EVAL] - Class loss: 11.236
# [EPOCH 3] - [EVAL] - Bbox loss : 19.386
#
# [EPOCH 4] - [B 0/94] - Class loss: 0.980
# [EPOCH 4] - [B 0/94] - Bbox loss : 16.636
# [EPOCH 4] - [B 10/94] - Class loss: 0.462
# [EPOCH 4] - [B 10/94] - Bbox loss : 33.579
# [EPOCH 4] - [B 20/94] - Class loss: 0.222
# [EPOCH 4] - [B 20/94] - Bbox loss : 19.254
# [EPOCH 4] - [B 30/94] - Class loss: 0.850
# [EPOCH 4] - [B 30/94] - Bbox loss : 8.681
# [EPOCH 4] - [B 40/94] - Class loss: 0.268
# [EPOCH 4] - [B 40/94] - Bbox loss : 11.340
# [EPOCH 4] - [B 50/94] - Class loss: 0.303
# [EPOCH 4] - [B 50/94] - Bbox loss : 25.487
# [EPOCH 4] - [B 60/94] - Class loss: 0.620
# [EPOCH 4] - [B 60/94] - Bbox loss : 19.925
# [EPOCH 4] - [B 70/94] - Class loss: 0.171
# [EPOCH 4] - [B 70/94] - Bbox loss : 29.085
# [EPOCH 4] - [B 80/94] - Class loss: 1.050
# [EPOCH 4] - [B 80/94] - Bbox loss : 19.025
# [EPOCH 4] - [B 90/94] - Class loss: 0.262
# [EPOCH 4] - [B 90/94] - Bbox loss : 23.741
# [EPOCH 4] - [EVAL] - Class loss: 14.183
# [EPOCH 4] - [EVAL] - Bbox loss : 17.365
#
# [EPOCH 5] - [B 0/94] - Class loss: 1.219
# [EPOCH 5] - [B 0/94] - Bbox loss : 16.755
# [EPOCH 5] - [B 10/94] - Class loss: 0.885
# [EPOCH 5] - [B 10/94] - Bbox loss : 30.537
# [EPOCH 5] - [B 20/94] - Class loss: 0.157
# [EPOCH 5] - [B 20/94] - Bbox loss : 20.921
# [EPOCH 5] - [B 30/94] - Class loss: 0.548
# [EPOCH 5] - [B 30/94] - Bbox loss : 10.217
# [EPOCH 5] - [B 40/94] - Class loss: 0.392
# [EPOCH 5] - [B 40/94] - Bbox loss : 13.854
# [EPOCH 5] - [B 50/94] - Class loss: 0.249
# [EPOCH 5] - [B 50/94] - Bbox loss : 25.457
# [EPOCH 5] - [B 60/94] - Class loss: 0.015
# [EPOCH 5] - [B 60/94] - Bbox loss : 18.406
# [EPOCH 5] - [B 70/94] - Class loss: 0.323
# [EPOCH 5] - [B 70/94] - Bbox loss : 26.603
# [EPOCH 5] - [B 80/94] - Class loss: 0.679
# [EPOCH 5] - [B 80/94] - Bbox loss : 14.944
# [EPOCH 5] - [B 90/94] - Class loss: 0.012
# [EPOCH 5] - [B 90/94] - Bbox loss : 23.916
# [EPOCH 5] - [EVAL] - Class loss: 14.344
# [EPOCH 5] - [EVAL] - Bbox loss : 16.693
#
# [EPOCH 6] - [B 0/94] - Class loss: 0.329
# [EPOCH 6] - [B 0/94] - Bbox loss : 13.983
# [EPOCH 6] - [B 10/94] - Class loss: 0.326
# [EPOCH 6] - [B 10/94] - Bbox loss : 26.227
# [EPOCH 6] - [B 20/94] - Class loss: 0.161
# [EPOCH 6] - [B 20/94] - Bbox loss : 20.575
# [EPOCH 6] - [B 30/94] - Class loss: 0.326
# [EPOCH 6] - [B 30/94] - Bbox loss : 10.899
# [EPOCH 6] - [B 40/94] - Class loss: 0.119
# [EPOCH 6] - [B 40/94] - Bbox loss : 13.189
# [EPOCH 6] - [B 50/94] - Class loss: 0.043
# [EPOCH 6] - [B 50/94] - Bbox loss : 24.175
# [EPOCH 6] - [B 60/94] - Class loss: 0.139
# [EPOCH 6] - [B 60/94] - Bbox loss : 19.918
# [EPOCH 6] - [B 70/94] - Class loss: 0.389
# [EPOCH 6] - [B 70/94] - Bbox loss : 28.665
# [EPOCH 6] - [B 80/94] - Class loss: 0.128
# [EPOCH 6] - [B 80/94] - Bbox loss : 15.118
# [EPOCH 6] - [B 90/94] - Class loss: 0.162
# [EPOCH 6] - [B 90/94] - Bbox loss : 23.337
# [EPOCH 6] - [EVAL] - Class loss: 15.866
# [EPOCH 6] - [EVAL] - Bbox loss : 17.634
#
# [EPOCH 7] - [B 0/94] - Class loss: 0.490
# [EPOCH 7] - [B 0/94] - Bbox loss : 14.776
# [EPOCH 7] - [B 10/94] - Class loss: 0.564
# [EPOCH 7] - [B 10/94] - Bbox loss : 33.592
# [EPOCH 7] - [B 20/94] - Class loss: 0.124
# [EPOCH 7] - [B 20/94] - Bbox loss : 22.580
# [EPOCH 7] - [B 30/94] - Class loss: 0.950
# [EPOCH 7] - [B 30/94] - Bbox loss : 10.217
# [EPOCH 7] - [B 40/94] - Class loss: 0.196
# [EPOCH 7] - [B 40/94] - Bbox loss : 16.026
# [EPOCH 7] - [B 50/94] - Class loss: 0.094
# [EPOCH 7] - [B 50/94] - Bbox loss : 23.009
# [EPOCH 7] - [B 60/94] - Class loss: 0.175
# [EPOCH 7] - [B 60/94] - Bbox loss : 14.378
# [EPOCH 7] - [B 70/94] - Class loss: 0.080
# [EPOCH 7] - [B 70/94] - Bbox loss : 22.685
# [EPOCH 7] - [B 80/94] - Class loss: 0.062
# [EPOCH 7] - [B 80/94] - Bbox loss : 14.032
# [EPOCH 7] - [B 90/94] - Class loss: 0.291
# [EPOCH 7] - [B 90/94] - Bbox loss : 21.448
# [EPOCH 7] - [EVAL] - Class loss: 15.027
# [EPOCH 7] - [EVAL] - Bbox loss : 16.812
#
# [EPOCH 8] - [B 0/94] - Class loss: 0.279
# [EPOCH 8] - [B 0/94] - Bbox loss : 12.412
# [EPOCH 8] - [B 10/94] - Class loss: 5.118
# [EPOCH 8] - [B 10/94] - Bbox loss : 27.533
# [EPOCH 8] - [B 20/94] - Class loss: 0.542
# [EPOCH 8] - [B 20/94] - Bbox loss : 18.078
# [EPOCH 8] - [B 30/94] - Class loss: 0.310
# [EPOCH 8] - [B 30/94] - Bbox loss : 8.301
# [EPOCH 8] - [B 40/94] - Class loss: 0.426
# [EPOCH 8] - [B 40/94] - Bbox loss : 9.740
# [EPOCH 8] - [B 50/94] - Class loss: 0.076
# [EPOCH 8] - [B 50/94] - Bbox loss : 21.918
# [EPOCH 8] - [B 60/94] - Class loss: 0.097
# [EPOCH 8] - [B 60/94] - Bbox loss : 14.750
# [EPOCH 8] - [B 70/94] - Class loss: 0.113
# [EPOCH 8] - [B 70/94] - Bbox loss : 23.018
# [EPOCH 8] - [B 80/94] - Class loss: 0.088
# [EPOCH 8] - [B 80/94] - Bbox loss : 12.886
# [EPOCH 8] - [B 90/94] - Class loss: 0.012
# [EPOCH 8] - [B 90/94] - Bbox loss : 21.603
# [EPOCH 8] - [EVAL] - Class loss: 20.496
# [EPOCH 8] - [EVAL] - Bbox loss : 14.200
#
# [EPOCH 9] - [B 0/94] - Class loss: 0.116
# [EPOCH 9] - [B 0/94] - Bbox loss : 12.371
# [EPOCH 9] - [B 10/94] - Class loss: 0.144
# [EPOCH 9] - [B 10/94] - Bbox loss : 28.107
# [EPOCH 9] - [B 20/94] - Class loss: 0.054
# [EPOCH 9] - [B 20/94] - Bbox loss : 20.421
# [EPOCH 9] - [B 30/94] - Class loss: 0.230
# [EPOCH 9] - [B 30/94] - Bbox loss : 7.021
# [EPOCH 9] - [B 40/94] - Class loss: 0.644
# [EPOCH 9] - [B 40/94] - Bbox loss : 8.937
# [EPOCH 9] - [B 50/94] - Class loss: 0.161
# [EPOCH 9] - [B 50/94] - Bbox loss : 20.394
# [EPOCH 9] - [B 60/94] - Class loss: 0.018
# [EPOCH 9] - [B 60/94] - Bbox loss : 13.450
# [EPOCH 9] - [B 70/94] - Class loss: 0.126
# [EPOCH 9] - [B 70/94] - Bbox loss : 21.634
# [EPOCH 9] - [B 80/94] - Class loss: 0.047
# [EPOCH 9] - [B 80/94] - Bbox loss : 13.402
# [EPOCH 9] - [B 90/94] - Class loss: 0.095
# [EPOCH 9] - [B 90/94] - Bbox loss : 21.182
# [EPOCH 9] - [EVAL] - Class loss: 19.550
# [EPOCH 9] - [EVAL] - Bbox loss : 15.424
#
# [EPOCH 10] - [B 0/94] - Class loss: 0.010
# [EPOCH 10] - [B 0/94] - Bbox loss : 11.183
# [EPOCH 10] - [B 10/94] - Class loss: 0.949
# [EPOCH 10] - [B 10/94] - Bbox loss : 25.759
# [EPOCH 10] - [B 20/94] - Class loss: 0.248
# [EPOCH 10] - [B 20/94] - Bbox loss : 19.858
# [EPOCH 10] - [B 30/94] - Class loss: 0.174
# [EPOCH 10] - [B 30/94] - Bbox loss : 7.596
# [EPOCH 10] - [B 40/94] - Class loss: 0.376
# [EPOCH 10] - [B 40/94] - Bbox loss : 9.367
# [EPOCH 10] - [B 50/94] - Class loss: 0.173
# [EPOCH 10] - [B 50/94] - Bbox loss : 21.224
# [EPOCH 10] - [B 60/94] - Class loss: 0.041
# [EPOCH 10] - [B 60/94] - Bbox loss : 12.521
# [EPOCH 10] - [B 70/94] - Class loss: 0.015
# [EPOCH 10] - [B 70/94] - Bbox loss : 21.316
# [EPOCH 10] - [B 80/94] - Class loss: 0.572
# [EPOCH 10] - [B 80/94] - Bbox loss : 14.231
# [EPOCH 10] - [B 90/94] - Class loss: 0.002
# [EPOCH 10] - [B 90/94] - Bbox loss : 23.627
# [EPOCH 10] - [EVAL] - Class loss: 18.935
# [EPOCH 10] - [EVAL] - Bbox loss : 15.233
#
# [EPOCH 11] - [B 0/94] - Class loss: 0.703
# [EPOCH 11] - [B 0/94] - Bbox loss : 10.297
# [EPOCH 11] - [B 10/94] - Class loss: 2.130
# [EPOCH 11] - [B 10/94] - Bbox loss : 26.380
# [EPOCH 11] - [B 20/94] - Class loss: 0.415
# [EPOCH 11] - [B 20/94] - Bbox loss : 19.563
# [EPOCH 11] - [B 30/94] - Class loss: 0.013
# [EPOCH 11] - [B 30/94] - Bbox loss : 10.538
# [EPOCH 11] - [B 40/94] - Class loss: 0.014
# [EPOCH 11] - [B 40/94] - Bbox loss : 13.950
# [EPOCH 11] - [B 50/94] - Class loss: 0.002
# [EPOCH 11] - [B 50/94] - Bbox loss : 19.564
# [EPOCH 11] - [B 60/94] - Class loss: 0.038
# [EPOCH 11] - [B 60/94] - Bbox loss : 14.196
# [EPOCH 11] - [B 70/94] - Class loss: 0.004
# [EPOCH 11] - [B 70/94] - Bbox loss : 22.780
# [EPOCH 11] - [B 80/94] - Class loss: 0.008
# [EPOCH 11] - [B 80/94] - Bbox loss : 11.077
# [EPOCH 11] - [B 90/94] - Class loss: 0.000
# [EPOCH 11] - [B 90/94] - Bbox loss : 20.738
# [EPOCH 11] - [EVAL] - Class loss: 23.563
# [EPOCH 11] - [EVAL] - Bbox loss : 14.413
#
# [EPOCH 12] - [B 0/94] - Class loss: 0.006
# [EPOCH 12] - [B 0/94] - Bbox loss : 11.096
# [EPOCH 12] - [B 10/94] - Class loss: 0.975
# [EPOCH 12] - [B 10/94] - Bbox loss : 23.870
# [EPOCH 12] - [B 20/94] - Class loss: 0.036
# [EPOCH 12] - [B 20/94] - Bbox loss : 17.049
# [EPOCH 12] - [B 30/94] - Class loss: 0.039
# [EPOCH 12] - [B 30/94] - Bbox loss : 6.261
# [EPOCH 12] - [B 40/94] - Class loss: 0.002
# [EPOCH 12] - [B 40/94] - Bbox loss : 10.562
# [EPOCH 12] - [B 50/94] - Class loss: 0.130
# [EPOCH 12] - [B 50/94] - Bbox loss : 19.580
# [EPOCH 12] - [B 60/94] - Class loss: 0.003
# [EPOCH 12] - [B 60/94] - Bbox loss : 12.408
# [EPOCH 12] - [B 70/94] - Class loss: 0.012
# [EPOCH 12] - [B 70/94] - Bbox loss : 22.639
# [EPOCH 12] - [B 80/94] - Class loss: 0.028
# [EPOCH 12] - [B 80/94] - Bbox loss : 11.904
# [EPOCH 12] - [B 90/94] - Class loss: 0.001
# [EPOCH 12] - [B 90/94] - Bbox loss : 20.452
# [EPOCH 12] - [EVAL] - Class loss: 21.715
# [EPOCH 12] - [EVAL] - Bbox loss : 14.069
#
# [EPOCH 13] - [B 0/94] - Class loss: 0.101
# [EPOCH 13] - [B 0/94] - Bbox loss : 9.834
# [EPOCH 13] - [B 10/94] - Class loss: 0.509
# [EPOCH 13] - [B 10/94] - Bbox loss : 24.079
# [EPOCH 13] - [B 20/94] - Class loss: 0.001
# [EPOCH 13] - [B 20/94] - Bbox loss : 17.345
# [EPOCH 13] - [B 30/94] - Class loss: 0.007
# [EPOCH 13] - [B 30/94] - Bbox loss : 4.626
# [EPOCH 13] - [B 40/94] - Class loss: 0.032
# [EPOCH 13] - [B 40/94] - Bbox loss : 10.423
# [EPOCH 13] - [B 50/94] - Class loss: 0.005
# [EPOCH 13] - [B 50/94] - Bbox loss : 20.890
# [EPOCH 13] - [B 60/94] - Class loss: 0.011
# [EPOCH 13] - [B 60/94] - Bbox loss : 12.515
# [EPOCH 13] - [B 70/94] - Class loss: 0.002
# [EPOCH 13] - [B 70/94] - Bbox loss : 23.824
# [EPOCH 13] - [B 80/94] - Class loss: 0.000
# [EPOCH 13] - [B 80/94] - Bbox loss : 12.009
# [EPOCH 13] - [B 90/94] - Class loss: 0.001
# [EPOCH 13] - [B 90/94] - Bbox loss : 19.997
# [EPOCH 13] - [EVAL] - Class loss: 21.743
# [EPOCH 13] - [EVAL] - Bbox loss : 14.571
#
# [EPOCH 14] - [B 0/94] - Class loss: 0.018
# [EPOCH 14] - [B 0/94] - Bbox loss : 7.559
# [EPOCH 14] - [B 10/94] - Class loss: 0.044
# [EPOCH 14] - [B 10/94] - Bbox loss : 25.144
# [EPOCH 14] - [B 20/94] - Class loss: 0.000
# [EPOCH 14] - [B 20/94] - Bbox loss : 15.872
# [EPOCH 14] - [B 30/94] - Class loss: 0.000
# [EPOCH 14] - [B 30/94] - Bbox loss : 4.502
# [EPOCH 14] - [B 40/94] - Class loss: 0.000
# [EPOCH 14] - [B 40/94] - Bbox loss : 8.196
# [EPOCH 14] - [B 50/94] - Class loss: 0.000
# [EPOCH 14] - [B 50/94] - Bbox loss : 18.163
# [EPOCH 14] - [B 60/94] - Class loss: 0.003
# [EPOCH 14] - [B 60/94] - Bbox loss : 14.738
# [EPOCH 14] - [B 70/94] - Class loss: 0.201
# [EPOCH 14] - [B 70/94] - Bbox loss : 24.606
# [EPOCH 14] - [B 80/94] - Class loss: 0.000
# [EPOCH 14] - [B 80/94] - Bbox loss : 12.555
# [EPOCH 14] - [B 90/94] - Class loss: 0.111
# [EPOCH 14] - [B 90/94] - Bbox loss : 23.454
# [EPOCH 14] - [EVAL] - Class loss: 20.386
# [EPOCH 14] - [EVAL] - Bbox loss : 16.038
#
# [EPOCH 15] - [B 0/94] - Class loss: 0.155
# [EPOCH 15] - [B 0/94] - Bbox loss : 8.359
# [EPOCH 15] - [B 10/94] - Class loss: 0.350
# [EPOCH 15] - [B 10/94] - Bbox loss : 22.072
# [EPOCH 15] - [B 20/94] - Class loss: 0.106
# [EPOCH 15] - [B 20/94] - Bbox loss : 15.987
# [EPOCH 15] - [B 30/94] - Class loss: 0.009
# [EPOCH 15] - [B 30/94] - Bbox loss : 5.416
# [EPOCH 15] - [B 40/94] - Class loss: 0.006
# [EPOCH 15] - [B 40/94] - Bbox loss : 12.995
# [EPOCH 15] - [B 50/94] - Class loss: 0.102
# [EPOCH 15] - [B 50/94] - Bbox loss : 20.408
# [EPOCH 15] - [B 60/94] - Class loss: 0.147
# [EPOCH 15] - [B 60/94] - Bbox loss : 12.053
# [EPOCH 15] - [B 70/94] - Class loss: 0.953
# [EPOCH 15] - [B 70/94] - Bbox loss : 24.306
# [EPOCH 15] - [B 80/94] - Class loss: 0.272
# [EPOCH 15] - [B 80/94] - Bbox loss : 14.230
# [EPOCH 15] - [B 90/94] - Class loss: 0.049
# [EPOCH 15] - [B 90/94] - Bbox loss : 20.733
# [EPOCH 15] - [EVAL] - Class loss: 21.801
# [EPOCH 15] - [EVAL] - Bbox loss : 15.407
#
# [EPOCH 16] - [B 0/94] - Class loss: 1.064
# [EPOCH 16] - [B 0/94] - Bbox loss : 9.082
# [EPOCH 16] - [B 10/94] - Class loss: 0.537
# [EPOCH 16] - [B 10/94] - Bbox loss : 23.919
# [EPOCH 16] - [B 20/94] - Class loss: 0.010
# [EPOCH 16] - [B 20/94] - Bbox loss : 16.110
# [EPOCH 16] - [B 30/94] - Class loss: 0.356
# [EPOCH 16] - [B 30/94] - Bbox loss : 8.486
# [EPOCH 16] - [B 40/94] - Class loss: 0.253
# [EPOCH 16] - [B 40/94] - Bbox loss : 11.141
# [EPOCH 16] - [B 50/94] - Class loss: 0.213
# [EPOCH 16] - [B 50/94] - Bbox loss : 19.844
# [EPOCH 16] - [B 60/94] - Class loss: 0.335
# [EPOCH 16] - [B 60/94] - Bbox loss : 13.247
# [EPOCH 16] - [B 70/94] - Class loss: 0.454
# [EPOCH 16] - [B 70/94] - Bbox loss : 20.954
# [EPOCH 16] - [B 80/94] - Class loss: 0.070
# [EPOCH 16] - [B 80/94] - Bbox loss : 12.006
# [EPOCH 16] - [B 90/94] - Class loss: 0.023
# [EPOCH 16] - [B 90/94] - Bbox loss : 20.672
# [EPOCH 16] - [EVAL] - Class loss: 24.989
# [EPOCH 16] - [EVAL] - Bbox loss : 17.378
#
# [EPOCH 17] - [B 0/94] - Class loss: 0.084
# [EPOCH 17] - [B 0/94] - Bbox loss : 12.220
# [EPOCH 17] - [B 10/94] - Class loss: 1.998
# [EPOCH 17] - [B 10/94] - Bbox loss : 22.209
# [EPOCH 17] - [B 20/94] - Class loss: 0.152
# [EPOCH 17] - [B 20/94] - Bbox loss : 16.928
# [EPOCH 17] - [B 30/94] - Class loss: 0.076
# [EPOCH 17] - [B 30/94] - Bbox loss : 10.390
# [EPOCH 17] - [B 40/94] - Class loss: 0.017
# [EPOCH 17] - [B 40/94] - Bbox loss : 9.529
# [EPOCH 17] - [B 50/94] - Class loss: 0.027
# [EPOCH 17] - [B 50/94] - Bbox loss : 18.156
# [EPOCH 17] - [B 60/94] - Class loss: 0.345
# [EPOCH 17] - [B 60/94] - Bbox loss : 12.392
# [EPOCH 17] - [B 70/94] - Class loss: 0.139
# [EPOCH 17] - [B 70/94] - Bbox loss : 20.239
# [EPOCH 17] - [B 80/94] - Class loss: 0.004
# [EPOCH 17] - [B 80/94] - Bbox loss : 12.241
# [EPOCH 17] - [B 90/94] - Class loss: 0.000
# [EPOCH 17] - [B 90/94] - Bbox loss : 21.368
# [EPOCH 17] - [EVAL] - Class loss: 23.368
# [EPOCH 17] - [EVAL] - Bbox loss : 16.059
#
# [EPOCH 18] - [B 0/94] - Class loss: 0.279
# [EPOCH 18] - [B 0/94] - Bbox loss : 8.569
# [EPOCH 18] - [B 10/94] - Class loss: 0.054
# [EPOCH 18] - [B 10/94] - Bbox loss : 23.978
# [EPOCH 18] - [B 20/94] - Class loss: 0.001
# [EPOCH 18] - [B 20/94] - Bbox loss : 15.471
# [EPOCH 18] - [B 30/94] - Class loss: 0.022
# [EPOCH 18] - [B 30/94] - Bbox loss : 5.424
# [EPOCH 18] - [B 40/94] - Class loss: 0.038
# [EPOCH 18] - [B 40/94] - Bbox loss : 8.981
# [EPOCH 18] - [B 50/94] - Class loss: 0.005
# [EPOCH 18] - [B 50/94] - Bbox loss : 18.003
# [EPOCH 18] - [B 60/94] - Class loss: 0.003
# [EPOCH 18] - [B 60/94] - Bbox loss : 11.628
# [EPOCH 18] - [B 70/94] - Class loss: 0.002
# [EPOCH 18] - [B 70/94] - Bbox loss : 20.967
# [EPOCH 18] - [B 80/94] - Class loss: 0.885
# [EPOCH 18] - [B 80/94] - Bbox loss : 10.896
# [EPOCH 18] - [B 90/94] - Class loss: 0.432
# [EPOCH 18] - [B 90/94] - Bbox loss : 19.933
# [EPOCH 18] - [EVAL] - Class loss: 22.401
# [EPOCH 18] - [EVAL] - Bbox loss : 14.053
#
# [EPOCH 19] - [B 0/94] - Class loss: 0.008
# [EPOCH 19] - [B 0/94] - Bbox loss : 9.852
# [EPOCH 19] - [B 10/94] - Class loss: 0.002
# [EPOCH 19] - [B 10/94] - Bbox loss : 22.435
# [EPOCH 19] - [B 20/94] - Class loss: 0.003
# [EPOCH 19] - [B 20/94] - Bbox loss : 15.675
# [EPOCH 19] - [B 30/94] - Class loss: 0.001
# [EPOCH 19] - [B 30/94] - Bbox loss : 7.712
# [EPOCH 19] - [B 40/94] - Class loss: 0.000
# [EPOCH 19] - [B 40/94] - Bbox loss : 12.134
# [EPOCH 19] - [B 50/94] - Class loss: 0.120
# [EPOCH 19] - [B 50/94] - Bbox loss : 19.610
# [EPOCH 19] - [B 60/94] - Class loss: 0.523
# [EPOCH 19] - [B 60/94] - Bbox loss : 12.002
# [EPOCH 19] - [B 70/94] - Class loss: 0.016
# [EPOCH 19] - [B 70/94] - Bbox loss : 20.438
# [EPOCH 19] - [B 80/94] - Class loss: 0.012
# [EPOCH 19] - [B 80/94] - Bbox loss : 11.819
# [EPOCH 19] - [B 90/94] - Class loss: 0.002
# [EPOCH 19] - [B 90/94] - Bbox loss : 19.322
# [EPOCH 19] - [EVAL] - Class loss: 23.658
# [EPOCH 19] - [EVAL] - Bbox loss : 15.676
#
# [EPOCH 20] - [B 0/94] - Class loss: 0.003
# [EPOCH 20] - [B 0/94] - Bbox loss : 10.571
# [EPOCH 20] - [B 10/94] - Class loss: 0.001
# [EPOCH 20] - [B 10/94] - Bbox loss : 20.858
# [EPOCH 20] - [B 20/94] - Class loss: 0.001
# [EPOCH 20] - [B 20/94] - Bbox loss : 15.056
# [EPOCH 20] - [B 30/94] - Class loss: 0.001
# [EPOCH 20] - [B 30/94] - Bbox loss : 4.227
# [EPOCH 20] - [B 40/94] - Class loss: 0.006
# [EPOCH 20] - [B 40/94] - Bbox loss : 8.624
# [EPOCH 20] - [B 50/94] - Class loss: 0.435
# [EPOCH 20] - [B 50/94] - Bbox loss : 17.293
# [EPOCH 20] - [B 60/94] - Class loss: 0.154
# [EPOCH 20] - [B 60/94] - Bbox loss : 18.703
# [EPOCH 20] - [B 70/94] - Class loss: 0.976
# [EPOCH 20] - [B 70/94] - Bbox loss : 21.217
# [EPOCH 20] - [B 80/94] - Class loss: 0.009
# [EPOCH 20] - [B 80/94] - Bbox loss : 12.948
# [EPOCH 20] - [B 90/94] - Class loss: 0.000
# [EPOCH 20] - [B 90/94] - Bbox loss : 19.664
# [EPOCH 20] - [EVAL] - Class loss: 25.171
# [EPOCH 20] - [EVAL] - Bbox loss : 14.214
#
# [EPOCH 21] - [B 0/94] - Class loss: 0.095
# [EPOCH 21] - [B 0/94] - Bbox loss : 8.433
# [EPOCH 21] - [B 10/94] - Class loss: 0.394
# [EPOCH 21] - [B 10/94] - Bbox loss : 21.701
# [EPOCH 21] - [B 20/94] - Class loss: 0.002
# [EPOCH 21] - [B 20/94] - Bbox loss : 14.524
# [EPOCH 21] - [B 30/94] - Class loss: 0.001
# [EPOCH 21] - [B 30/94] - Bbox loss : 4.095
# [EPOCH 21] - [B 40/94] - Class loss: 0.040
# [EPOCH 21] - [B 40/94] - Bbox loss : 7.006
# [EPOCH 21] - [B 50/94] - Class loss: 0.000
# [EPOCH 21] - [B 50/94] - Bbox loss : 18.334
# [EPOCH 21] - [B 60/94] - Class loss: 0.000
# [EPOCH 21] - [B 60/94] - Bbox loss : 18.635
# [EPOCH 21] - [B 70/94] - Class loss: 0.003
# [EPOCH 21] - [B 70/94] - Bbox loss : 21.668
# [EPOCH 21] - [B 80/94] - Class loss: 0.003
# [EPOCH 21] - [B 80/94] - Bbox loss : 11.553
# [EPOCH 21] - [B 90/94] - Class loss: 0.011
# [EPOCH 21] - [B 90/94] - Bbox loss : 20.431
# [EPOCH 21] - [EVAL] - Class loss: 23.855
# [EPOCH 21] - [EVAL] - Bbox loss : 13.974
#
# [EPOCH 22] - [B 0/94] - Class loss: 0.017
# [EPOCH 22] - [B 0/94] - Bbox loss : 10.706
# [EPOCH 22] - [B 10/94] - Class loss: 0.120
# [EPOCH 22] - [B 10/94] - Bbox loss : 22.451
# [EPOCH 22] - [B 20/94] - Class loss: 0.002
# [EPOCH 22] - [B 20/94] - Bbox loss : 17.499
# [EPOCH 22] - [B 30/94] - Class loss: 0.000
# [EPOCH 22] - [B 30/94] - Bbox loss : 7.205
# [EPOCH 22] - [B 40/94] - Class loss: 0.000
# [EPOCH 22] - [B 40/94] - Bbox loss : 10.415
# [EPOCH 22] - [B 50/94] - Class loss: 0.000
# [EPOCH 22] - [B 50/94] - Bbox loss : 20.439
# [EPOCH 22] - [B 60/94] - Class loss: 0.000
# [EPOCH 22] - [B 60/94] - Bbox loss : 13.030
# [EPOCH 22] - [B 70/94] - Class loss: 0.023
# [EPOCH 22] - [B 70/94] - Bbox loss : 20.446
# [EPOCH 22] - [B 80/94] - Class loss: 0.003
# [EPOCH 22] - [B 80/94] - Bbox loss : 12.577
# [EPOCH 22] - [B 90/94] - Class loss: 0.001
# [EPOCH 22] - [B 90/94] - Bbox loss : 18.985
# [EPOCH 22] - [EVAL] - Class loss: 24.430
# [EPOCH 22] - [EVAL] - Bbox loss : 13.371
#
# [EPOCH 23] - [B 0/94] - Class loss: 0.007
# [EPOCH 23] - [B 0/94] - Bbox loss : 6.940
# [EPOCH 23] - [B 10/94] - Class loss: 0.136
# [EPOCH 23] - [B 10/94] - Bbox loss : 21.325
# [EPOCH 23] - [B 20/94] - Class loss: 0.003
# [EPOCH 23] - [B 20/94] - Bbox loss : 15.390
# [EPOCH 23] - [B 30/94] - Class loss: 0.762
# [EPOCH 23] - [B 30/94] - Bbox loss : 4.931
# [EPOCH 23] - [B 40/94] - Class loss: 0.014
# [EPOCH 23] - [B 40/94] - Bbox loss : 8.875
# [EPOCH 23] - [B 50/94] - Class loss: 0.061
# [EPOCH 23] - [B 50/94] - Bbox loss : 17.130
# [EPOCH 23] - [B 60/94] - Class loss: 0.001
# [EPOCH 23] - [B 60/94] - Bbox loss : 12.115
# [EPOCH 23] - [B 70/94] - Class loss: 0.016
# [EPOCH 23] - [B 70/94] - Bbox loss : 19.253
# [EPOCH 23] - [B 80/94] - Class loss: 0.005
# [EPOCH 23] - [B 80/94] - Bbox loss : 12.501
# [EPOCH 23] - [B 90/94] - Class loss: 0.001
# [EPOCH 23] - [B 90/94] - Bbox loss : 21.094
# [EPOCH 23] - [EVAL] - Class loss: 26.035
# [EPOCH 23] - [EVAL] - Bbox loss : 14.785
#
# [EPOCH 24] - [B 0/94] - Class loss: 0.330
# [EPOCH 24] - [B 0/94] - Bbox loss : 9.801
# [EPOCH 24] - [B 10/94] - Class loss: 0.004
# [EPOCH 24] - [B 10/94] - Bbox loss : 20.343
# [EPOCH 24] - [B 20/94] - Class loss: 0.000
# [EPOCH 24] - [B 20/94] - Bbox loss : 14.365
# [EPOCH 24] - [B 30/94] - Class loss: 0.002
# [EPOCH 24] - [B 30/94] - Bbox loss : 3.628
# [EPOCH 24] - [B 40/94] - Class loss: 0.056
# [EPOCH 24] - [B 40/94] - Bbox loss : 7.521
# [EPOCH 24] - [B 50/94] - Class loss: 0.050
# [EPOCH 24] - [B 50/94] - Bbox loss : 16.151
# [EPOCH 24] - [B 60/94] - Class loss: 0.001
# [EPOCH 24] - [B 60/94] - Bbox loss : 12.955
# [EPOCH 24] - [B 70/94] - Class loss: 0.006
# [EPOCH 24] - [B 70/94] - Bbox loss : 18.049
# [EPOCH 24] - [B 80/94] - Class loss: 0.000
# [EPOCH 24] - [B 80/94] - Bbox loss : 11.471
# [EPOCH 24] - [B 90/94] - Class loss: 0.017
# [EPOCH 24] - [B 90/94] - Bbox loss : 20.274
# [EPOCH 24] - [EVAL] - Class loss: 22.893
# [EPOCH 24] - [EVAL] - Bbox loss : 14.183
#
# [EPOCH 25] - [B 0/94] - Class loss: 0.068
# [EPOCH 25] - [B 0/94] - Bbox loss : 6.838
# [EPOCH 25] - [B 10/94] - Class loss: 0.015
# [EPOCH 25] - [B 10/94] - Bbox loss : 20.373
# [EPOCH 25] - [B 20/94] - Class loss: 0.000
# [EPOCH 25] - [B 20/94] - Bbox loss : 14.976
# [EPOCH 25] - [B 30/94] - Class loss: 0.013
# [EPOCH 25] - [B 30/94] - Bbox loss : 7.168
# [EPOCH 25] - [B 40/94] - Class loss: 0.000
# [EPOCH 25] - [B 40/94] - Bbox loss : 11.187
# [EPOCH 25] - [B 50/94] - Class loss: 0.001
# [EPOCH 25] - [B 50/94] - Bbox loss : 17.873
# [EPOCH 25] - [B 60/94] - Class loss: 0.000
# [EPOCH 25] - [B 60/94] - Bbox loss : 12.058
# [EPOCH 25] - [B 70/94] - Class loss: 0.001
# [EPOCH 25] - [B 70/94] - Bbox loss : 17.948
# [EPOCH 25] - [B 80/94] - Class loss: 0.001
# [EPOCH 25] - [B 80/94] - Bbox loss : 10.955
# [EPOCH 25] - [B 90/94] - Class loss: 0.000
# [EPOCH 25] - [B 90/94] - Bbox loss : 17.923
# [EPOCH 25] - [EVAL] - Class loss: 25.197
# [EPOCH 25] - [EVAL] - Bbox loss : 13.569
#
# [EPOCH 26] - [B 0/94] - Class loss: 0.000
# [EPOCH 26] - [B 0/94] - Bbox loss : 7.111
# [EPOCH 26] - [B 10/94] - Class loss: 0.000
# [EPOCH 26] - [B 10/94] - Bbox loss : 21.319
# [EPOCH 26] - [B 20/94] - Class loss: 0.000
# [EPOCH 26] - [B 20/94] - Bbox loss : 15.041
# [EPOCH 26] - [B 30/94] - Class loss: 0.002
# [EPOCH 26] - [B 30/94] - Bbox loss : 8.888
# [EPOCH 26] - [B 40/94] - Class loss: 0.058
# [EPOCH 26] - [B 40/94] - Bbox loss : 11.147
# [EPOCH 26] - [B 50/94] - Class loss: 0.000
# [EPOCH 26] - [B 50/94] - Bbox loss : 15.385
# [EPOCH 26] - [B 60/94] - Class loss: 0.373
# [EPOCH 26] - [B 60/94] - Bbox loss : 10.440
# [EPOCH 26] - [B 70/94] - Class loss: 0.030
# [EPOCH 26] - [B 70/94] - Bbox loss : 19.254
# [EPOCH 26] - [B 80/94] - Class loss: 0.271
# [EPOCH 26] - [B 80/94] - Bbox loss : 15.183
# [EPOCH 26] - [B 90/94] - Class loss: 0.001
# [EPOCH 26] - [B 90/94] - Bbox loss : 22.337
# [EPOCH 26] - [EVAL] - Class loss: 27.373
# [EPOCH 26] - [EVAL] - Bbox loss : 15.077
#
# [EPOCH 27] - [B 0/94] - Class loss: 0.000
# [EPOCH 27] - [B 0/94] - Bbox loss : 9.479
# [EPOCH 27] - [B 10/94] - Class loss: 0.002
# [EPOCH 27] - [B 10/94] - Bbox loss : 24.194
# [EPOCH 27] - [B 20/94] - Class loss: 0.001
# [EPOCH 27] - [B 20/94] - Bbox loss : 16.270
# [EPOCH 27] - [B 30/94] - Class loss: 0.002
# [EPOCH 27] - [B 30/94] - Bbox loss : 9.791
# [EPOCH 27] - [B 40/94] - Class loss: 0.077
# [EPOCH 27] - [B 40/94] - Bbox loss : 10.501
# [EPOCH 27] - [B 50/94] - Class loss: 0.005
# [EPOCH 27] - [B 50/94] - Bbox loss : 21.147
# [EPOCH 27] - [B 60/94] - Class loss: 0.087
# [EPOCH 27] - [B 60/94] - Bbox loss : 12.413
# [EPOCH 27] - [B 70/94] - Class loss: 0.202
# [EPOCH 27] - [B 70/94] - Bbox loss : 20.937
# [EPOCH 27] - [B 80/94] - Class loss: 0.011
# [EPOCH 27] - [B 80/94] - Bbox loss : 17.430
# [EPOCH 27] - [B 90/94] - Class loss: 0.007
# [EPOCH 27] - [B 90/94] - Bbox loss : 20.379
# [EPOCH 27] - [EVAL] - Class loss: 28.327
# [EPOCH 27] - [EVAL] - Bbox loss : 18.549
#
# [EPOCH 28] - [B 0/94] - Class loss: 0.528
# [EPOCH 28] - [B 0/94] - Bbox loss : 14.224
# [EPOCH 28] - [B 10/94] - Class loss: 0.044
# [EPOCH 28] - [B 10/94] - Bbox loss : 19.481
# [EPOCH 28] - [B 20/94] - Class loss: 0.131
# [EPOCH 28] - [B 20/94] - Bbox loss : 16.259
# [EPOCH 28] - [B 30/94] - Class loss: 0.089
# [EPOCH 28] - [B 30/94] - Bbox loss : 6.165
# [EPOCH 28] - [B 40/94] - Class loss: 0.028
# [EPOCH 28] - [B 40/94] - Bbox loss : 7.805
# [EPOCH 28] - [B 50/94] - Class loss: 0.001
# [EPOCH 28] - [B 50/94] - Bbox loss : 18.448
# [EPOCH 28] - [B 60/94] - Class loss: 0.650
# [EPOCH 28] - [B 60/94] - Bbox loss : 11.377
# [EPOCH 28] - [B 70/94] - Class loss: 0.666
# [EPOCH 28] - [B 70/94] - Bbox loss : 21.405
# [EPOCH 28] - [B 80/94] - Class loss: 1.155
# [EPOCH 28] - [B 80/94] - Bbox loss : 15.735
# [EPOCH 28] - [B 90/94] - Class loss: 0.024
# [EPOCH 28] - [B 90/94] - Bbox loss : 19.746
# [EPOCH 28] - [EVAL] - Class loss: 32.248
# [EPOCH 28] - [EVAL] - Bbox loss : 16.780
#
# [EPOCH 29] - [B 0/94] - Class loss: 1.117
# [EPOCH 29] - [B 0/94] - Bbox loss : 10.848
# [EPOCH 29] - [B 10/94] - Class loss: 2.186
# [EPOCH 29] - [B 10/94] - Bbox loss : 20.716
# [EPOCH 29] - [B 20/94] - Class loss: 0.310
# [EPOCH 29] - [B 20/94] - Bbox loss : 14.771
# [EPOCH 29] - [B 30/94] - Class loss: 0.067
# [EPOCH 29] - [B 30/94] - Bbox loss : 6.608
# [EPOCH 29] - [B 40/94] - Class loss: 0.008
# [EPOCH 29] - [B 40/94] - Bbox loss : 8.301
# [EPOCH 29] - [B 50/94] - Class loss: 0.983
# [EPOCH 29] - [B 50/94] - Bbox loss : 17.886
# [EPOCH 29] - [B 60/94] - Class loss: 0.000
# [EPOCH 29] - [B 60/94] - Bbox loss : 10.439
# [EPOCH 29] - [B 70/94] - Class loss: 0.156
# [EPOCH 29] - [B 70/94] - Bbox loss : 19.606
# [EPOCH 29] - [B 80/94] - Class loss: 0.229
# [EPOCH 29] - [B 80/94] - Bbox loss : 12.336
# [EPOCH 29] - [B 90/94] - Class loss: 0.002
# [EPOCH 29] - [B 90/94] - Bbox loss : 19.230
# [EPOCH 29] - [EVAL] - Class loss: 30.723
# [EPOCH 29] - [EVAL] - Bbox loss : 16.502
#
# [EPOCH 30] - [B 0/94] - Class loss: 0.021
# [EPOCH 30] - [B 0/94] - Bbox loss : 10.288
# [EPOCH 30] - [B 10/94] - Class loss: 0.052
# [EPOCH 30] - [B 10/94] - Bbox loss : 20.317
# [EPOCH 30] - [B 20/94] - Class loss: 0.000
# [EPOCH 30] - [B 20/94] - Bbox loss : 14.868
# [EPOCH 30] - [B 30/94] - Class loss: 0.323
# [EPOCH 30] - [B 30/94] - Bbox loss : 4.430
# [EPOCH 30] - [B 40/94] - Class loss: 0.000
# [EPOCH 30] - [B 40/94] - Bbox loss : 8.263
# [EPOCH 30] - [B 50/94] - Class loss: 0.001
# [EPOCH 30] - [B 50/94] - Bbox loss : 17.999
# [EPOCH 30] - [B 60/94] - Class loss: 0.011
# [EPOCH 30] - [B 60/94] - Bbox loss : 11.397
# [EPOCH 30] - [B 70/94] - Class loss: 0.046
# [EPOCH 30] - [B 70/94] - Bbox loss : 18.555
# [EPOCH 30] - [B 80/94] - Class loss: 0.036
# [EPOCH 30] - [B 80/94] - Bbox loss : 10.610
# [EPOCH 30] - [B 90/94] - Class loss: 0.000
# [EPOCH 30] - [B 90/94] - Bbox loss : 18.705
# [EPOCH 30] - [EVAL] - Class loss: 30.765
# [EPOCH 30] - [EVAL] - Bbox loss : 13.673
#
# [EPOCH 31] - [B 0/94] - Class loss: 0.008
# [EPOCH 31] - [B 0/94] - Bbox loss : 6.674
# [EPOCH 31] - [B 10/94] - Class loss: 0.000
# [EPOCH 31] - [B 10/94] - Bbox loss : 18.835
# [EPOCH 31] - [B 20/94] - Class loss: 0.000
# [EPOCH 31] - [B 20/94] - Bbox loss : 13.988
# [EPOCH 31] - [B 30/94] - Class loss: 0.000
# [EPOCH 31] - [B 30/94] - Bbox loss : 4.917
# [EPOCH 31] - [B 40/94] - Class loss: 0.000
# [EPOCH 31] - [B 40/94] - Bbox loss : 7.753
# [EPOCH 31] - [B 50/94] - Class loss: 0.000
# [EPOCH 31] - [B 50/94] - Bbox loss : 17.055
# [EPOCH 31] - [B 60/94] - Class loss: 0.000
# [EPOCH 31] - [B 60/94] - Bbox loss : 10.880
# [EPOCH 31] - [B 70/94] - Class loss: 0.000
# [EPOCH 31] - [B 70/94] - Bbox loss : 17.231
# [EPOCH 31] - [B 80/94] - Class loss: 0.000
# [EPOCH 31] - [B 80/94] - Bbox loss : 13.405
# [EPOCH 31] - [B 90/94] - Class loss: 0.000
# [EPOCH 31] - [B 90/94] - Bbox loss : 16.639
# [EPOCH 31] - [EVAL] - Class loss: 29.019
# [EPOCH 31] - [EVAL] - Bbox loss : 15.354
#
# [EPOCH 32] - [B 0/94] - Class loss: 0.001
# [EPOCH 32] - [B 0/94] - Bbox loss : 8.265
# [EPOCH 32] - [B 10/94] - Class loss: 0.000
# [EPOCH 32] - [B 10/94] - Bbox loss : 18.099
# [EPOCH 32] - [B 20/94] - Class loss: 0.000
# [EPOCH 32] - [B 20/94] - Bbox loss : 15.261
# [EPOCH 32] - [B 30/94] - Class loss: 0.000
# [EPOCH 32] - [B 30/94] - Bbox loss : 4.870
# [EPOCH 32] - [B 40/94] - Class loss: 0.000
# [EPOCH 32] - [B 40/94] - Bbox loss : 9.525
# [EPOCH 32] - [B 50/94] - Class loss: 0.001
# [EPOCH 32] - [B 50/94] - Bbox loss : 17.392
# [EPOCH 32] - [B 60/94] - Class loss: 0.000
# [EPOCH 32] - [B 60/94] - Bbox loss : 9.526
# [EPOCH 32] - [B 70/94] - Class loss: 0.000
# [EPOCH 32] - [B 70/94] - Bbox loss : 20.166
# [EPOCH 32] - [B 80/94] - Class loss: 0.004
# [EPOCH 32] - [B 80/94] - Bbox loss : 11.840
# [EPOCH 32] - [B 90/94] - Class loss: 0.000
# [EPOCH 32] - [B 90/94] - Bbox loss : 23.371
# [EPOCH 32] - [EVAL] - Class loss: 29.493
# [EPOCH 32] - [EVAL] - Bbox loss : 16.541
#
# [EPOCH 33] - [B 0/94] - Class loss: 0.009
# [EPOCH 33] - [B 0/94] - Bbox loss : 11.844
# [EPOCH 33] - [B 10/94] - Class loss: 0.006
# [EPOCH 33] - [B 10/94] - Bbox loss : 22.000
# [EPOCH 33] - [B 20/94] - Class loss: 0.001
# [EPOCH 33] - [B 20/94] - Bbox loss : 24.258
# [EPOCH 33] - [B 30/94] - Class loss: 0.003
# [EPOCH 33] - [B 30/94] - Bbox loss : 10.846
# [EPOCH 33] - [B 40/94] - Class loss: 0.000
# [EPOCH 33] - [B 40/94] - Bbox loss : 10.237
# [EPOCH 33] - [B 50/94] - Class loss: 0.006
# [EPOCH 33] - [B 50/94] - Bbox loss : 23.341
# [EPOCH 33] - [B 60/94] - Class loss: 0.000
# [EPOCH 33] - [B 60/94] - Bbox loss : 17.247
# [EPOCH 33] - [B 70/94] - Class loss: 0.004
# [EPOCH 33] - [B 70/94] - Bbox loss : 20.551
# [EPOCH 33] - [B 80/94] - Class loss: 0.003
# [EPOCH 33] - [B 80/94] - Bbox loss : 12.878
# [EPOCH 33] - [B 90/94] - Class loss: 0.000
# [EPOCH 33] - [B 90/94] - Bbox loss : 20.583
# [EPOCH 33] - [EVAL] - Class loss: 26.573
# [EPOCH 33] - [EVAL] - Bbox loss : 15.487
#
# [EPOCH 34] - [B 0/94] - Class loss: 0.031
# [EPOCH 34] - [B 0/94] - Bbox loss : 9.906
# [EPOCH 34] - [B 10/94] - Class loss: 0.004
# [EPOCH 34] - [B 10/94] - Bbox loss : 17.683
# [EPOCH 34] - [B 20/94] - Class loss: 0.652
# [EPOCH 34] - [B 20/94] - Bbox loss : 16.247
# [EPOCH 34] - [B 30/94] - Class loss: 0.000
# [EPOCH 34] - [B 30/94] - Bbox loss : 6.681
# [EPOCH 34] - [B 40/94] - Class loss: 0.000
# [EPOCH 34] - [B 40/94] - Bbox loss : 8.833
# [EPOCH 34] - [B 50/94] - Class loss: 0.000
# [EPOCH 34] - [B 50/94] - Bbox loss : 21.925
# [EPOCH 34] - [B 60/94] - Class loss: 0.000
# [EPOCH 34] - [B 60/94] - Bbox loss : 19.315
# [EPOCH 34] - [B 70/94] - Class loss: 0.008
# [EPOCH 34] - [B 70/94] - Bbox loss : 24.370
# [EPOCH 34] - [B 80/94] - Class loss: 0.000
# [EPOCH 34] - [B 80/94] - Bbox loss : 14.643
# [EPOCH 34] - [B 90/94] - Class loss: 0.117
# [EPOCH 34] - [B 90/94] - Bbox loss : 18.908
# [EPOCH 34] - [EVAL] - Class loss: 31.155
# [EPOCH 34] - [EVAL] - Bbox loss : 16.823
#
# [EPOCH 35] - [B 0/94] - Class loss: 0.843
# [EPOCH 35] - [B 0/94] - Bbox loss : 10.185
# [EPOCH 35] - [B 10/94] - Class loss: 0.435
# [EPOCH 35] - [B 10/94] - Bbox loss : 17.437
# [EPOCH 35] - [B 20/94] - Class loss: 0.599
# [EPOCH 35] - [B 20/94] - Bbox loss : 16.212
# [EPOCH 35] - [B 30/94] - Class loss: 0.048
# [EPOCH 35] - [B 30/94] - Bbox loss : 5.592
# [EPOCH 35] - [B 40/94] - Class loss: 0.036
# [EPOCH 35] - [B 40/94] - Bbox loss : 8.266
# [EPOCH 35] - [B 50/94] - Class loss: 0.542
# [EPOCH 35] - [B 50/94] - Bbox loss : 21.657
# [EPOCH 35] - [B 60/94] - Class loss: 0.683
# [EPOCH 35] - [B 60/94] - Bbox loss : 14.874
# [EPOCH 35] - [B 70/94] - Class loss: 0.264
# [EPOCH 35] - [B 70/94] - Bbox loss : 22.815
# [EPOCH 35] - [B 80/94] - Class loss: 0.012
# [EPOCH 35] - [B 80/94] - Bbox loss : 12.867
# [EPOCH 35] - [B 90/94] - Class loss: 1.182
# [EPOCH 35] - [B 90/94] - Bbox loss : 21.639
# [EPOCH 35] - [EVAL] - Class loss: 38.843
# [EPOCH 35] - [EVAL] - Bbox loss : 15.901
#
# [EPOCH 36] - [B 0/94] - Class loss: 0.588
# [EPOCH 36] - [B 0/94] - Bbox loss : 8.848
# [EPOCH 36] - [B 10/94] - Class loss: 7.167
# [EPOCH 36] - [B 10/94] - Bbox loss : 26.048
# [EPOCH 36] - [B 20/94] - Class loss: 0.050
# [EPOCH 36] - [B 20/94] - Bbox loss : 14.663
# [EPOCH 36] - [B 30/94] - Class loss: 1.200
# [EPOCH 36] - [B 30/94] - Bbox loss : 7.184
# [EPOCH 36] - [B 40/94] - Class loss: 0.255
# [EPOCH 36] - [B 40/94] - Bbox loss : 10.501
# [EPOCH 36] - [B 50/94] - Class loss: 0.007
# [EPOCH 36] - [B 50/94] - Bbox loss : 21.763
# [EPOCH 36] - [B 60/94] - Class loss: 0.055
# [EPOCH 36] - [B 60/94] - Bbox loss : 13.049
# [EPOCH 36] - [B 70/94] - Class loss: 0.531
# [EPOCH 36] - [B 70/94] - Bbox loss : 21.223
# [EPOCH 36] - [B 80/94] - Class loss: 0.938
# [EPOCH 36] - [B 80/94] - Bbox loss : 11.955
# [EPOCH 36] - [B 90/94] - Class loss: 1.377
# [EPOCH 36] - [B 90/94] - Bbox loss : 19.794
# [EPOCH 36] - [EVAL] - Class loss: 32.727
# [EPOCH 36] - [EVAL] - Bbox loss : 14.238
#
# [EPOCH 37] - [B 0/94] - Class loss: 0.008
# [EPOCH 37] - [B 0/94] - Bbox loss : 7.766
# [EPOCH 37] - [B 10/94] - Class loss: 2.217
# [EPOCH 37] - [B 10/94] - Bbox loss : 25.636
# [EPOCH 37] - [B 20/94] - Class loss: 0.454
# [EPOCH 37] - [B 20/94] - Bbox loss : 17.045
# [EPOCH 37] - [B 30/94] - Class loss: 0.021
# [EPOCH 37] - [B 30/94] - Bbox loss : 6.322
# [EPOCH 37] - [B 40/94] - Class loss: 0.392
# [EPOCH 37] - [B 40/94] - Bbox loss : 8.952
# [EPOCH 37] - [B 50/94] - Class loss: 0.565
# [EPOCH 37] - [B 50/94] - Bbox loss : 17.808
# [EPOCH 37] - [B 60/94] - Class loss: 0.000
# [EPOCH 37] - [B 60/94] - Bbox loss : 12.059
# [EPOCH 37] - [B 70/94] - Class loss: 0.722
# [EPOCH 37] - [B 70/94] - Bbox loss : 20.228
# [EPOCH 37] - [B 80/94] - Class loss: 0.004
# [EPOCH 37] - [B 80/94] - Bbox loss : 11.315
# [EPOCH 37] - [B 90/94] - Class loss: 0.003
# [EPOCH 37] - [B 90/94] - Bbox loss : 18.224
# [EPOCH 37] - [EVAL] - Class loss: 33.436
# [EPOCH 37] - [EVAL] - Bbox loss : 13.821
#
# [EPOCH 38] - [B 0/94] - Class loss: 0.349
# [EPOCH 38] - [B 0/94] - Bbox loss : 6.780
# [EPOCH 38] - [B 10/94] - Class loss: 0.123
# [EPOCH 38] - [B 10/94] - Bbox loss : 20.770
# [EPOCH 38] - [B 20/94] - Class loss: 0.175
# [EPOCH 38] - [B 20/94] - Bbox loss : 14.382
# [EPOCH 38] - [B 30/94] - Class loss: 0.000
# [EPOCH 38] - [B 30/94] - Bbox loss : 4.776
# [EPOCH 38] - [B 40/94] - Class loss: 0.000
# [EPOCH 38] - [B 40/94] - Bbox loss : 8.256
# [EPOCH 38] - [B 50/94] - Class loss: 0.061
# [EPOCH 38] - [B 50/94] - Bbox loss : 17.472
# [EPOCH 38] - [B 60/94] - Class loss: 0.001
# [EPOCH 38] - [B 60/94] - Bbox loss : 10.709
# [EPOCH 38] - [B 70/94] - Class loss: 0.000
# [EPOCH 38] - [B 70/94] - Bbox loss : 19.677
# [EPOCH 38] - [B 80/94] - Class loss: 0.000
# [EPOCH 38] - [B 80/94] - Bbox loss : 10.835
# [EPOCH 38] - [B 90/94] - Class loss: 0.000
# [EPOCH 38] - [B 90/94] - Bbox loss : 17.141
# [EPOCH 38] - [EVAL] - Class loss: 36.977
# [EPOCH 38] - [EVAL] - Bbox loss : 13.393
#
# [EPOCH 39] - [B 0/94] - Class loss: 0.018
# [EPOCH 39] - [B 0/94] - Bbox loss : 5.829
# [EPOCH 39] - [B 10/94] - Class loss: 0.000
# [EPOCH 39] - [B 10/94] - Bbox loss : 19.272
# [EPOCH 39] - [B 20/94] - Class loss: 0.000
# [EPOCH 39] - [B 20/94] - Bbox loss : 14.305
# [EPOCH 39] - [B 30/94] - Class loss: 0.000
# [EPOCH 39] - [B 30/94] - Bbox loss : 5.283
# [EPOCH 39] - [B 40/94] - Class loss: 0.000
# [EPOCH 39] - [B 40/94] - Bbox loss : 8.539
# [EPOCH 39] - [B 50/94] - Class loss: 0.000
# [EPOCH 39] - [B 50/94] - Bbox loss : 16.025
# [EPOCH 39] - [B 60/94] - Class loss: 0.000
# [EPOCH 39] - [B 60/94] - Bbox loss : 9.739
# [EPOCH 39] - [B 70/94] - Class loss: 0.000
# [EPOCH 39] - [B 70/94] - Bbox loss : 17.860
# [EPOCH 39] - [B 80/94] - Class loss: 0.002
# [EPOCH 39] - [B 80/94] - Bbox loss : 10.622
# [EPOCH 39] - [B 90/94] - Class loss: 0.000
# [EPOCH 39] - [B 90/94] - Bbox loss : 16.922
# [EPOCH 39] - [EVAL] - Class loss: 34.814
# [EPOCH 39] - [EVAL] - Bbox loss : 13.345
#
# [EPOCH 40] - [B 0/94] - Class loss: 0.000
# [EPOCH 40] - [B 0/94] - Bbox loss : 6.160
# [EPOCH 40] - [B 10/94] - Class loss: 0.000
# [EPOCH 40] - [B 10/94] - Bbox loss : 17.451
# [EPOCH 40] - [B 20/94] - Class loss: 0.000
# [EPOCH 40] - [B 20/94] - Bbox loss : 13.866
# [EPOCH 40] - [B 30/94] - Class loss: 0.000
# [EPOCH 40] - [B 30/94] - Bbox loss : 4.487
# [EPOCH 40] - [B 40/94] - Class loss: 0.000
# [EPOCH 40] - [B 40/94] - Bbox loss : 7.945
# [EPOCH 40] - [B 50/94] - Class loss: 0.000
# [EPOCH 40] - [B 50/94] - Bbox loss : 16.153
# [EPOCH 40] - [B 60/94] - Class loss: 0.000
# [EPOCH 40] - [B 60/94] - Bbox loss : 10.743
# [EPOCH 40] - [B 70/94] - Class loss: 0.000
# [EPOCH 40] - [B 70/94] - Bbox loss : 17.386
# [EPOCH 40] - [B 80/94] - Class loss: 0.000
# [EPOCH 40] - [B 80/94] - Bbox loss : 12.148
# [EPOCH 40] - [B 90/94] - Class loss: 0.000
# [EPOCH 40] - [B 90/94] - Bbox loss : 16.691
# [EPOCH 40] - [EVAL] - Class loss: 33.138
# [EPOCH 40] - [EVAL] - Bbox loss : 13.038
#
# [EPOCH 41] - [B 0/94] - Class loss: 0.001
# [EPOCH 41] - [B 0/94] - Bbox loss : 7.743
# [EPOCH 41] - [B 10/94] - Class loss: 0.003
# [EPOCH 41] - [B 10/94] - Bbox loss : 17.140
# [EPOCH 41] - [B 20/94] - Class loss: 0.000
# [EPOCH 41] - [B 20/94] - Bbox loss : 13.317
# [EPOCH 41] - [B 30/94] - Class loss: 0.000
# [EPOCH 41] - [B 30/94] - Bbox loss : 3.142
# [EPOCH 41] - [B 40/94] - Class loss: 0.000
# [EPOCH 41] - [B 40/94] - Bbox loss : 7.494
# [EPOCH 41] - [B 50/94] - Class loss: 0.000
# [EPOCH 41] - [B 50/94] - Bbox loss : 20.173
# [EPOCH 41] - [B 60/94] - Class loss: 0.000
# [EPOCH 41] - [B 60/94] - Bbox loss : 20.058
# [EPOCH 41] - [B 70/94] - Class loss: 0.000
# [EPOCH 41] - [B 70/94] - Bbox loss : 18.609
# [EPOCH 41] - [B 80/94] - Class loss: 0.000
# [EPOCH 41] - [B 80/94] - Bbox loss : 10.862
# [EPOCH 41] - [B 90/94] - Class loss: 0.000
# [EPOCH 41] - [B 90/94] - Bbox loss : 21.809
# [EPOCH 41] - [EVAL] - Class loss: 31.848
# [EPOCH 41] - [EVAL] - Bbox loss : 14.365
#
# [EPOCH 42] - [B 0/94] - Class loss: 0.000
# [EPOCH 42] - [B 0/94] - Bbox loss : 6.330
# [EPOCH 42] - [B 10/94] - Class loss: 0.002
# [EPOCH 42] - [B 10/94] - Bbox loss : 21.301
# [EPOCH 42] - [B 20/94] - Class loss: 0.000
# [EPOCH 42] - [B 20/94] - Bbox loss : 14.135
# [EPOCH 42] - [B 30/94] - Class loss: 0.000
# [EPOCH 42] - [B 30/94] - Bbox loss : 3.458
# [EPOCH 42] - [B 40/94] - Class loss: 0.000
# [EPOCH 42] - [B 40/94] - Bbox loss : 9.761
# [EPOCH 42] - [B 50/94] - Class loss: 0.001
# [EPOCH 42] - [B 50/94] - Bbox loss : 17.760
# [EPOCH 42] - [B 60/94] - Class loss: 0.000
# [EPOCH 42] - [B 60/94] - Bbox loss : 19.495
# [EPOCH 42] - [B 70/94] - Class loss: 0.000
# [EPOCH 42] - [B 70/94] - Bbox loss : 24.388
# [EPOCH 42] - [B 80/94] - Class loss: 0.000
# [EPOCH 42] - [B 80/94] - Bbox loss : 15.046
# [EPOCH 42] - [B 90/94] - Class loss: 0.000
# [EPOCH 42] - [B 90/94] - Bbox loss : 18.382
# [EPOCH 42] - [EVAL] - Class loss: 32.724
# [EPOCH 42] - [EVAL] - Bbox loss : 15.135
#
# [EPOCH 43] - [B 0/94] - Class loss: 0.000
# [EPOCH 43] - [B 0/94] - Bbox loss : 8.508
# [EPOCH 43] - [B 10/94] - Class loss: 0.001
# [EPOCH 43] - [B 10/94] - Bbox loss : 16.067
# [EPOCH 43] - [B 20/94] - Class loss: 0.000
# [EPOCH 43] - [B 20/94] - Bbox loss : 17.138
# [EPOCH 43] - [B 30/94] - Class loss: 0.000
# [EPOCH 43] - [B 30/94] - Bbox loss : 3.687
# [EPOCH 43] - [B 40/94] - Class loss: 0.000
# [EPOCH 43] - [B 40/94] - Bbox loss : 7.003
# [EPOCH 43] - [B 50/94] - Class loss: 0.002
# [EPOCH 43] - [B 50/94] - Bbox loss : 15.642
# [EPOCH 43] - [B 60/94] - Class loss: 0.000
# [EPOCH 43] - [B 60/94] - Bbox loss : 16.668
# [EPOCH 43] - [B 70/94] - Class loss: 0.000
# [EPOCH 43] - [B 70/94] - Bbox loss : 20.593
# [EPOCH 43] - [B 80/94] - Class loss: 0.000
# [EPOCH 43] - [B 80/94] - Bbox loss : 19.105
# [EPOCH 43] - [B 90/94] - Class loss: 0.000
# [EPOCH 43] - [B 90/94] - Bbox loss : 21.976
# [EPOCH 43] - [EVAL] - Class loss: 32.547
# [EPOCH 43] - [EVAL] - Bbox loss : 16.386
#
# [EPOCH 44] - [B 0/94] - Class loss: 0.000
# [EPOCH 44] - [B 0/94] - Bbox loss : 9.582
# [EPOCH 44] - [B 10/94] - Class loss: 0.000
# [EPOCH 44] - [B 10/94] - Bbox loss : 19.817
# [EPOCH 44] - [B 20/94] - Class loss: 0.000
# [EPOCH 44] - [B 20/94] - Bbox loss : 13.941
# [EPOCH 44] - [B 30/94] - Class loss: 0.000
# [EPOCH 44] - [B 30/94] - Bbox loss : 4.650
# [EPOCH 44] - [B 40/94] - Class loss: 0.000
# [EPOCH 44] - [B 40/94] - Bbox loss : 6.296
# [EPOCH 44] - [B 50/94] - Class loss: 0.000
# [EPOCH 44] - [B 50/94] - Bbox loss : 14.632
# [EPOCH 44] - [B 60/94] - Class loss: 0.000
# [EPOCH 44] - [B 60/94] - Bbox loss : 11.989
# [EPOCH 44] - [B 70/94] - Class loss: 0.000
# [EPOCH 44] - [B 70/94] - Bbox loss : 17.922
# [EPOCH 44] - [B 80/94] - Class loss: 0.000
# [EPOCH 44] - [B 80/94] - Bbox loss : 14.577
# [EPOCH 44] - [B 90/94] - Class loss: 0.000
# [EPOCH 44] - [B 90/94] - Bbox loss : 18.142
# [EPOCH 44] - [EVAL] - Class loss: 30.939
# [EPOCH 44] - [EVAL] - Bbox loss : 15.120
#
# [EPOCH 45] - [B 0/94] - Class loss: 0.000
# [EPOCH 45] - [B 0/94] - Bbox loss : 6.489
# [EPOCH 45] - [B 10/94] - Class loss: 0.001
# [EPOCH 45] - [B 10/94] - Bbox loss : 18.500
# [EPOCH 45] - [B 20/94] - Class loss: 0.000
# [EPOCH 45] - [B 20/94] - Bbox loss : 14.851
# [EPOCH 45] - [B 30/94] - Class loss: 0.000
# [EPOCH 45] - [B 30/94] - Bbox loss : 3.657
# [EPOCH 45] - [B 40/94] - Class loss: 0.000
# [EPOCH 45] - [B 40/94] - Bbox loss : 11.251
# [EPOCH 45] - [B 50/94] - Class loss: 0.000
# [EPOCH 45] - [B 50/94] - Bbox loss : 17.914
# [EPOCH 45] - [B 60/94] - Class loss: 0.000
# [EPOCH 45] - [B 60/94] - Bbox loss : 14.127
# [EPOCH 45] - [B 70/94] - Class loss: 0.000
# [EPOCH 45] - [B 70/94] - Bbox loss : 20.967
# [EPOCH 45] - [B 80/94] - Class loss: 0.000
# [EPOCH 45] - [B 80/94] - Bbox loss : 16.692
# [EPOCH 45] - [B 90/94] - Class loss: 0.000
# [EPOCH 45] - [B 90/94] - Bbox loss : 21.828
# [EPOCH 45] - [EVAL] - Class loss: 29.434
# [EPOCH 45] - [EVAL] - Bbox loss : 13.058
#
# [EPOCH 46] - [B 0/94] - Class loss: 0.000
# [EPOCH 46] - [B 0/94] - Bbox loss : 8.590
# [EPOCH 46] - [B 10/94] - Class loss: 0.002
# [EPOCH 46] - [B 10/94] - Bbox loss : 15.989
# [EPOCH 46] - [B 20/94] - Class loss: 0.000
# [EPOCH 46] - [B 20/94] - Bbox loss : 16.193
# [EPOCH 46] - [B 30/94] - Class loss: 0.000
# [EPOCH 46] - [B 30/94] - Bbox loss : 6.851
# [EPOCH 46] - [B 40/94] - Class loss: 0.000
# [EPOCH 46] - [B 40/94] - Bbox loss : 7.390
# [EPOCH 46] - [B 50/94] - Class loss: 0.000
# [EPOCH 46] - [B 50/94] - Bbox loss : 15.808
# [EPOCH 46] - [B 60/94] - Class loss: 0.000
# [EPOCH 46] - [B 60/94] - Bbox loss : 10.017
# [EPOCH 46] - [B 70/94] - Class loss: 0.000
# [EPOCH 46] - [B 70/94] - Bbox loss : 19.491
# [EPOCH 46] - [B 80/94] - Class loss: 0.000
# [EPOCH 46] - [B 80/94] - Bbox loss : 11.482
# [EPOCH 46] - [B 90/94] - Class loss: 0.000
# [EPOCH 46] - [B 90/94] - Bbox loss : 18.298
# [EPOCH 46] - [EVAL] - Class loss: 28.654
# [EPOCH 46] - [EVAL] - Bbox loss : 12.965
#
# [EPOCH 47] - [B 0/94] - Class loss: 0.000
# [EPOCH 47] - [B 0/94] - Bbox loss : 6.478
# [EPOCH 47] - [B 10/94] - Class loss: 0.003
# [EPOCH 47] - [B 10/94] - Bbox loss : 14.983
# [EPOCH 47] - [B 20/94] - Class loss: 0.000
# [EPOCH 47] - [B 20/94] - Bbox loss : 13.960
# [EPOCH 47] - [B 30/94] - Class loss: 0.000
# [EPOCH 47] - [B 30/94] - Bbox loss : 4.477
# [EPOCH 47] - [B 40/94] - Class loss: 0.000
# [EPOCH 47] - [B 40/94] - Bbox loss : 8.819
# [EPOCH 47] - [B 50/94] - Class loss: 0.000
# [EPOCH 47] - [B 50/94] - Bbox loss : 15.120
# [EPOCH 47] - [B 60/94] - Class loss: 0.000
# [EPOCH 47] - [B 60/94] - Bbox loss : 12.543
# [EPOCH 47] - [B 70/94] - Class loss: 0.000
# [EPOCH 47] - [B 70/94] - Bbox loss : 19.641
# [EPOCH 47] - [B 80/94] - Class loss: 0.000
# [EPOCH 47] - [B 80/94] - Bbox loss : 9.885
# [EPOCH 47] - [B 90/94] - Class loss: 0.000
# [EPOCH 47] - [B 90/94] - Bbox loss : 17.538
# [EPOCH 47] - [EVAL] - Class loss: 27.406
# [EPOCH 47] - [EVAL] - Bbox loss : 17.143
#
# [EPOCH 48] - [B 0/94] - Class loss: 0.000
# [EPOCH 48] - [B 0/94] - Bbox loss : 17.194
# [EPOCH 48] - [B 10/94] - Class loss: 0.002
# [EPOCH 48] - [B 10/94] - Bbox loss : 19.893
# [EPOCH 48] - [B 20/94] - Class loss: 0.000
# [EPOCH 48] - [B 20/94] - Bbox loss : 21.544
# [EPOCH 48] - [B 30/94] - Class loss: 0.000
# [EPOCH 48] - [B 30/94] - Bbox loss : 10.540
# [EPOCH 48] - [B 40/94] - Class loss: 0.001
# [EPOCH 48] - [B 40/94] - Bbox loss : 8.646
# [EPOCH 48] - [B 50/94] - Class loss: 0.001
# [EPOCH 48] - [B 50/94] - Bbox loss : 17.835
# [EPOCH 48] - [B 60/94] - Class loss: 0.000
# [EPOCH 48] - [B 60/94] - Bbox loss : 9.738
# [EPOCH 48] - [B 70/94] - Class loss: 0.000
# [EPOCH 48] - [B 70/94] - Bbox loss : 18.026
# [EPOCH 48] - [B 80/94] - Class loss: 0.000
# [EPOCH 48] - [B 80/94] - Bbox loss : 10.595
# [EPOCH 48] - [B 90/94] - Class loss: 0.000
# [EPOCH 48] - [B 90/94] - Bbox loss : 18.528
# [EPOCH 48] - [EVAL] - Class loss: 26.811
# [EPOCH 48] - [EVAL] - Bbox loss : 18.315
#
# [EPOCH 49] - [B 0/94] - Class loss: 0.013
# [EPOCH 49] - [B 0/94] - Bbox loss : 13.637
# [EPOCH 49] - [B 10/94] - Class loss: 0.000
# [EPOCH 49] - [B 10/94] - Bbox loss : 19.183
# [EPOCH 49] - [B 20/94] - Class loss: 0.000
# [EPOCH 49] - [B 20/94] - Bbox loss : 20.021
# [EPOCH 49] - [B 30/94] - Class loss: 0.000
# [EPOCH 49] - [B 30/94] - Bbox loss : 13.248
# [EPOCH 49] - [B 40/94] - Class loss: 0.001
# [EPOCH 49] - [B 40/94] - Bbox loss : 14.631
# [EPOCH 49] - [B 50/94] - Class loss: 0.003
# [EPOCH 49] - [B 50/94] - Bbox loss : 17.369
# [EPOCH 49] - [B 60/94] - Class loss: 0.000
# [EPOCH 49] - [B 60/94] - Bbox loss : 10.806
# [EPOCH 49] - [B 70/94] - Class loss: 0.000
# [EPOCH 49] - [B 70/94] - Bbox loss : 16.710
# [EPOCH 49] - [B 80/94] - Class loss: 0.000
# [EPOCH 49] - [B 80/94] - Bbox loss : 11.549
# [EPOCH 49] - [B 90/94] - Class loss: 0.001
# [EPOCH 49] - [B 90/94] - Bbox loss : 19.121
# [EPOCH 49] - [EVAL] - Class loss: 27.310
# [EPOCH 49] - [EVAL] - Bbox loss : 15.025
#
# [EPOCH 50] - [B 0/94] - Class loss: 0.001
# [EPOCH 50] - [B 0/94] - Bbox loss : 8.373
# [EPOCH 50] - [B 10/94] - Class loss: 0.001
# [EPOCH 50] - [B 10/94] - Bbox loss : 17.054
# [EPOCH 50] - [B 20/94] - Class loss: 0.000
# [EPOCH 50] - [B 20/94] - Bbox loss : 17.138
# [EPOCH 50] - [B 30/94] - Class loss: 0.000
# [EPOCH 50] - [B 30/94] - Bbox loss : 11.797
# [EPOCH 50] - [B 40/94] - Class loss: 0.000
# [EPOCH 50] - [B 40/94] - Bbox loss : 9.802
# [EPOCH 50] - [B 50/94] - Class loss: 0.004
# [EPOCH 50] - [B 50/94] - Bbox loss : 17.618
# [EPOCH 50] - [B 60/94] - Class loss: 0.000
# [EPOCH 50] - [B 60/94] - Bbox loss : 11.274
# [EPOCH 50] - [B 70/94] - Class loss: 0.000
# [EPOCH 50] - [B 70/94] - Bbox loss : 16.954
# [EPOCH 50] - [B 80/94] - Class loss: 0.003
# [EPOCH 50] - [B 80/94] - Bbox loss : 12.099
# [EPOCH 50] - [B 90/94] - Class loss: 0.000
# [EPOCH 50] - [B 90/94] - Bbox loss : 20.487
# [EPOCH 50] - [EVAL] - Class loss: 27.247
# [EPOCH 50] - [EVAL] - Bbox loss : 15.140

# %%
plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
plt.plot(metrics["train_class"])
plt.title("Training - Class")
plt.subplot(2, 2, 2)
plt.plot(metrics["train_bbox"])
plt.title("Training - BBOX")
plt.subplot(2, 2, 3)
plt.plot(metrics["valid_class"], color="orange")
plt.title("Validation - Class")
plt.subplot(2, 2, 4)
plt.plot(metrics["valid_bbox"], color="orange")
plt.title("Validation - BBOX")
plt.suptitle("Training curves")
plt.tight_layout()

# %%
ims_, ys_, bboxes_ = next(iter(val_loader))
y_preds, box_preds = model(ims_.to(device))

# %%
width_wise = 3
height_wise = 4
fig, ax = plt.subplots(width_wise, height_wise)
fig.set_size_inches((10, 8))
for i in range(width_wise):
    for j in range(height_wise):
        idx = i * height_wise + j
        this_ax = ax[i][j]
        display_img_mask(ims_[idx], y_preds[idx].argmax(), box_preds[idx].cpu().detach(), ax=this_ax, linewidth=1)
        # display_img_mask(image, y, bbox, ax=this_ax, linewidth=1)
        this_ax.set_axis_off()
